# %% [raw]
# ###1.The recurrence relation T(n) = 3T(n-1) + 12n with T(0) = 5 can be solved using the substitution method. We can obtain the following expression for T(n):
#
# T(n) = 3^n * T(0) + 12 * (3^(n-1) + 3^(n-2) + … + 3^1 + 3^0) * n
#
# Simplifying the geometric series, we get:
#
# T(n) = 3^n * T(0) + 12 * (3^n - 1) / 2 * n
#
# Substituting n = 2 and T(0) = 5, we get:
#
# T(2) = 3^2 * 5 + 12 * (3^2 - 1) / 2 * 2
#
# T(2) = 45 + 12 * 8
#
# T(2) = 141
#
# Therefore, the value of T(2) for the given recurrence relation is 141.
#
# T(n) = 3[3T(n-2) + 12(n-1)] + 12n
# T(n) = 9T(n-2) + 36(n-1) + 12n
# T(n) = 3^2 * T(n-2) + 48n - 36
#
# Substituting n = 2 and T(0) = 5, we get:
#
# T(2) = 9T(2-2) + 48(2) - 36
# T(2) = 9(5) + 48(2) - 36
# T(2) = 45 + 96 -36
# T(2) = 105

# %% [raw]
# ### 2. Given a rec%rrence relation, solve it %sing the s%bstit%tion method:
#
# a. T(n) = T(n-1) + c
# we take base case condition as 1
# T(n) = T(n-1) + c
# THE VALUE OF "(n-1)","n-2"
# T(n-1) = T(n-2) + c
# T(n-2) = T(n-3) + c
# NOW PUT THE VALU OF "T(n-1)" in T(n)
# T(n) = T(n-2) + 2c
# NOW PUT THE VALU OF "T(n-2)" IN "T(n)"
# T(n) = T(n-3) + 3c
# now we concider "k" time
# T(n) = T(n-k) + kc
# according our base case condition "n-k = 1" so "k" value is "n-1"
# now puting "k" value in T(n)
# T(n) = T(n-n+1) + (n-1)c
# T(n) = T(1) + nc-c
# so the bigger value is n
# so time complaxity is" O(n) "

# %% [raw]
# ##b. T(n) = 2T(n/2) + n
#    we take base case condition as 1
#    T(n/2) = 2T(n/2^2) + n/2
#    T(n/2^2) = 2T(n/2^3) + n/2^2
# put the value of T(n/2)
#    T(n) = 2[2T(n/2^2) + n/2] + n
#    T(n) = 2^2T(n/2^2) + n +n
# put the value of T(n/2^2) in T(n)
#    T(n) = 2^2[2T(n/2^3) + n/2^2] +n+n
#    T(n) = 2^3T(n/2^3) + 3n
# now concider it "k" time
#    T(n) = 2^k.T(n/2^k)  + kn ---- "1"
# acording to base case condition
# n/2^k = 1
# n = 2^k
# take log of both side then
# k = log base 2 the  n (logn)
# now puting "k" value in equation "1"
# so we got,
#          T(n) = 2^log base 2 the  n (logn) .T(n/2^log base 2 the  n (logn)) + log base 2  (logn).n
#          so T(n) = n.1 + logn.n
# so time complaxityis O(n.logn)
# or time complaxity is O(n.log base 2 and n)

# %% [raw]
# ##c. T(n) = 2T(n/2) + c----- 1
# we take base case condition as 1
#      T(n/2) = 2T(n/2^2) + c-------2
#      T(n/2^2) = 2T(n/2^3) + c------3
# NOW PUT THE VALUE OF T(n/2) IN T(n)
#      T(n) = 2[2T(n/2^2)] + 2c
#      T(n) = 2^2T(n/2^2) + 2c
# NOW PUT THE VALUE T(N/2^2) IN T(n)
#      T(n) = 2^2[2T(n/2^3)] + 3c
#      T(n) = 2^3T(n/2^3) + 3c
# now concider "k" time
#      T(n) = 2^k.T(n/2^k) + k.c------4
# acording to base case "n = 2^k"
# take log of both side with base 2
# logn = log2^k
# k = logn
# now put the value of k in equation 4
#     T(n) = n.1 + logn.c
# so time complaxity is O(logn)
# or O(base 2 log n)

# %% [raw]
# ## d. T(n) = T(n/2) + c
# T(n) = T(n/2^2)+ 2c
# T(n) = T(n/2^3) + 3c
# T(n) = T(n/2^k) + k.c
# n/2^k = 1-----1
# n = 2^k----2
# TAKE LOG OF BOTH SIDE
# logn = log2^k
# logn = k(log2 base 2)
# logn = k-----3
# puting the valu in T(n)
# T(n) = T(1)+ logn.c
# SO TIME COMPLAXITY IS O(logn)

# %% [raw]
# ### 3. Given a rec%rrence relation, solve it %sing the rec%rsive tree approach:
# # a. T(n) = 2T(n-1) +1
# T(n) = T(n-1) +  T(n-1) + 1
#                                                                     T(n)----------(2^0)
#                                                                      |
#                                                                       |
#                                                                       |
#                                                                       /\
#                                                                 T(n-1)  T(n-1)---------(2^1)
#                                                                   |        |
#                                                                   /\        |\
#                                                             T(n-2)   T(n-2) T(n-2)  T(n-2)------------(2^2)
#
# we take base case condition as "0"
# now we concider we do that task "k " time
# 2^0,2^1,2^2_____2^k-------(this is G.P series)
# a = 1
# r = 2
# from the base case (n-k=0)
# from the base case (n=k)
# sum of G.P = a(r^n-1)/r-1
# so sum of G.P =  2^k-1
# now put the value of k == n
# so the TIME COMPLAXITY IS O(2^n)

# %% [raw]
# ### b. T(n) = 2T(n/2) + n                                             this whole task doing k time and work n time so total work == k.n
# T(n) = T(n/2)+T(n/2) + n
#                                                                  |-------------T(n)-----------(n)
#                                                                  |             |
#                                                                  |             |
#                                                                  |             |
#                                                               k  |            / \
#                                                                  |       T(n/2)  T(n/2)----------(2(n/2)=n)
#                                                                  |          |       |
#                                                                  |          |       |
#                                                                  |          |       |
#                                                                  |          /  \     |\
#                                                                  ----T(n/2^2) T(n/2^2)| T(n/2^2)----------(4(n/4)=n)
#                                                                                    |
#                                                                                    T(n/2^2)
#
#
# we take base case condition as 1 when our code stop
# n/2^k = 1
# n = 2^k
# take log of both side
# logn =log2^k
# take base as 2
# logn = k
# now we have k value so k.n === n.logn
# so TIME COMPLAXITY IS O(n.logn)
